# %% [markdown]
# # Analisis de informacion, inicial o Analisis Exploratorio

# %% [markdown]
# ### Vamos a examinar un DATASET en Formato EXCEL

# %% [markdown]
# > Son **Datos** de las elecciones de 2019 en una localidad alejada de un centro urbano principal como la ciudad fronteriza de **La** **Quiaca**, usaremos **PANDAS** = Python Analysis Dats

# %%
import pandas as pd

# %%
datos = pd.read_excel('LAQUIACA-2019-JUNIO.xlsx')

# %%
print (datos)
# Out:
#        MESA  ORDEN           ESCUELA TIPO DE EJEMPLAR  MATRICULA APELLIDO  \
# 0      1620      1               EET           DNI-EA    8000677   PRIETO
# 1      1620      2               EET              DNI   28314207    ABALO
# 2      1620      3               EET           DNI-EA   33844704    ABALO
# 3      1620      4               EET           DNI-EA    8012954    ABALO
# 4      1620      5               EET           DNI-EB   28727558    ABALO
# ...     ...    ...               ...              ...        ...      ...
# 14299  1662    328  ESCUELA FRONTERA           DNI-EA   41401783   ZUTARA
# 14300  1662    329  ESCUELA FRONTERA           DNI-EA   39401859   ZUTARA
# 14301  1662    330  ESCUELA FRONTERA           DNI-ED   40765421   ZUTARA
# 14302  1662    331  ESCUELA FRONTERA           DNI-EC   12231832   ZUTARA
# 14303  1662    332  ESCUELA FRONTERA           DNI-EC   21319985   ZUTARA
#
#                 NOMBRE  CLASE GENERO  \
# 0          RAUL MANUEL   1948      M
# ...

# %%
print(list(datos.columns.values))
# Out:
# ['MESA', 'ORDEN', 'ESCUELA', 'TIPO DE EJEMPLAR', 'MATRICULA', 'APELLIDO', 'NOMBRE', 'CLASE', 'GENERO', 'DOMICILIO', 'SECCION', 'CIRCUITO', 'MESA.1', 'ORDEN_MESA', 'ESCUELA.1', 'TX_SECC_NUMERO', 'TX_CIRC_NUMERO']

# %%
datos = pd.read_excel('Padron-Final-2019JUJUY.xlsx')

# %%
print (datos)
# Out:
#        TIPO DE EJEMPLAR  MATRICULA    APELLIDO  \
# 0                DNI-EA   18859749  ABAL CHICA
# 1                DNI-EB   13121180      ABALOS
# 2                DNI-EB   41041579        ABAN
# 3                DNI-EB   40820282        ABAN
# 4                DNI-EA   18256434        ABAN
# ...                 ...        ...         ...
# 547497           DNI-EB   43790684       VILTE
# 547498           DNI-EA   42954854     VIVEROS
# 547499           DNI-EC   34970523     VIVEROS
# 547500        NO CONSTA   21318470     VIVEROS
# 547501              DNI    7281571       ZERPA
#
#                                      NOMBRE  CLASE GENERO  \
# 0                            ROXANA SILVANA   1976      F
# 1                         ANGÉLICA HERMINIA   1959      F
# 2                           ALVARO EZEQUIEL   1998      M
# 3                          CARLA EVANGELINA   1997      F
# 4                                   CLAUDIA   1966      F
# ...

# %%
print(list(datos.columns.values))
# Out:
# ['TIPO DE EJEMPLAR', 'MATRICULA', 'APELLIDO', 'NOMBRE', 'CLASE', 'GENERO', 'DOMICILIO', 'SECCION', 'CIRCUITO', 'MESA', 'ORDEN', 'TX_CODIGO_TIPO_ELECTOR', 'TX_SECC_NUMERO', 'TX_CIRC_NUMERO', 'TX_COLOR']

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# > https://relopezbriega.github.io/blog/2015/06/27/probabilidad-y-estadistica-con-python/

# %%
## GRAFICA MODO TORTA o PIE...
plot_torta = datos['SECCION'].value_counts().plot(kind='pie', autopct='%.2f', figsize=(12, 12),
                                            title='PORCENTAJE de VOTANTES por Dpto de Jujuy')
plt.show()

# %%
datos['GENERO'].value_counts()
# Out:
# F    276936
# M    270566
# Name: GENERO, dtype: int64

# %%
## GRAFICA MODO TORTA o PIE...
plot_torta = datos['GENERO'].value_counts().plot(kind='pie', autopct='%.2f', figsize=(12, 12),
                                            title='PORCENTAJE de VOTANTES por GENERO en Jujuy 2019')
plt.show()

# %%
datos['SECCION'].value_counts()
# Out:
# 1 - DR. MANUEL BELGRANO    213621
# 4 - EL CARMEN               75207
# 7 - LEDESMA                 65617
# 5 - SAN PEDRO               62533
# 2 - PALPALA                 44500
# 15 - YAVI                   17523
# 6 - SANTA BARBARA           14661
# 11 - HUMAHUACA              14186
# 10 - TILCARA                10528
# 12 - COCHINOCA              10284
# 9 - TUMBAYA                  4855
# 3 - SAN ANTONIO              4201
# 16 - SUSQUES                 3065
# 8 - VALLE GRANDE             2663
# 14 - SANTA CATALINA          2550
# 13 - RINCONADA               1508
# Name: SECCION, dtype: int64

# %% [markdown]
# ## Otra Forma de hacer Graficas

# %%
import matplotlib.pyplot as plt

info = [200,150,250,300]
nombresnatura = ["Santiago","Rocio","Day","Romina"]
plt.pie(info, labels=nombresnatura, autopct="%0.1f %%")
plt.axis("equal")
plt.show()

# %% [markdown]
# # Ejemplo del Sitio Web SCIPYTHON

# %%
import numpy as np
import matplotlib.pyplot as plt

countries = ['Brazil', 'Madagascar', 'S. Korea', 'United States',
             'Ethiopia', 'Pakistan', 'China', 'Belize']
# Birth rate per 1000 population
birth_rate = [16.4, 33.5, 9.5, 14.2, 38.6, 30.2, 13.5, 23.0]
# Life expectancy at birth, years
life_expectancy = [73.7, 64.3, 81.3, 78.8, 63.0, 66.4, 75.2, 73.7]
# Per person income fixed to US Dollars in 2000
GDP = np.array([4800, 240, 16700, 37700, 230, 670, 2640, 3490])

fig = plt.figure()
ax = fig.add_subplot(111)
# Some random colours: 
colours = range(len(countries))
ax.scatter(birth_rate, life_expectancy, c=colours, s=GDP/20)
ax.set_xlim(5, 45)
ax.set_ylim(60, 85)
ax.set_xlabel('Birth rate per 1000 population')
ax.set_ylabel('Life expectancy at birth (years)')

offset = 1
for x, y, s, country in zip(birth_rate, life_expectancy, GDP, countries):
    ax.text(x+offset, y, country, va='center')


plt.show()
