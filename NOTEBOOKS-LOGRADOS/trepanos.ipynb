# %% [markdown]
# ## Santiago Zuleta - Practica 1

# %% [markdown]
# ### Graficas de trepanos en el VPS Unsa Central desde Tartagal

# %%
import pandas as pd

# %%
datos = pd.read_excel('trepanos_python.xlsx')

# %%
print(list(datos.columns.values))
# Out:
# ['Nº INVENTARIO', 'NOMBRE DEL TREPANO', 'PAIS-ORIGEN', 'TIPO', 'COJINETES', 'FECHA-COMPRA', 'DESGASTE', 'CANT', 'COSTO']

# %%
print (datos)
# Out:
#    Nº INVENTARIO NOMBRE DEL TREPANO PAIS-ORIGEN      TIPO      COJINETES  \
# 0            A10            TRACK28        EEUU       PDC  SIN COJINETES
# 1            A20            EZ CASE        EEUU  MONOCONO      SIN SELLO
# 2            A30             RW2021      MEXICO    BICONO      SIN SELLO
# 3            A40           POWER-56    ALEMANIA       PDC  SIN COJINETES
# 4            A50          WZP54-MIT      MEXICO       PDC  SIN COJINETES
# 5            A60      NAT-DIAM/2222        EEUU    CORONA      CON SELLO
# 6            A70              XZ-32        EEUU    CORONA      CON SELLO
# 7            A80     ESTANDAR XZ-32      MEXICO   TRICONO      CON SELLO
# 8            A90           HEDGEHOG     FRANCIA    CORONA      CON SELLO
# 9           A100         NEW-IRON78        EEUU   TRICONO      CON SELLO
# 10          A110           BALLASET      MEXICO   TRICONO      CON SELLO
# 11          A120           EXODUS32     FRANCIA   TRICONO      CON SELLO
# ...

# %%
import matplotlib.pyplot as plt

# %%
## GRAFICA MODO TORTA o PIE...
plot_torta = datos['TIPO'].value_counts().plot(kind='pie', autopct='%.2f', figsize=(8, 8),
                                            title='TREPANOS')
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
##---------------------------------------------------------------
## GRAFICA MODO BARRAS HORIZONTALES por eso es: BARH
plot_barras = datos['TIPO'].value_counts().plot(kind='barh', figsize=(12, 12), title='TREPANO')
plt.show()

# %%
##---------------------------------------------------------------
## GRAFICA MODO BARRAS HORIZONTALES por eso es: BARH
plot_barras = datos['TIPO'].value_counts().plot(kind='bar', figsize=(12, 12), title='TREPANO')
plt.show()
