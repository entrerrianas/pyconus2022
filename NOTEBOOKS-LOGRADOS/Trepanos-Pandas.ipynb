# %% [markdown]
# # Santiago Zuleta - Práctica 1
#
# ### Graficas en VPS Unsa Central desde Tartagal

# %% [markdown]
# ### Primer paso
# 1) importar la libreria

# %%
import pandas as pd

# %%
serie = pd.Series([1,2,3])

# %% [markdown]
# #### serie igual a columna

# %%
serie
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
serie.name='nombre'

# %%
serie
# Out:
# 0    1
# 1    2
# 2    3
# Name: nombre, dtype: int64

# %% [markdown]
# ##### Para crear columna y sus valores

# %%
df = pd.DataFrame({'columna1':[1,2,3,4],'columna2':['a','b','c','d']})

# %%
df
# Out:
#    columna1 columna2
# 0         1        a
# 1         2        b
# 2         3        c
# 3         4        d

# %% [markdown]
# ##### para definir las filas y columnas

# %%
df.shape
# Out:
# (4, 2)

# %% [markdown]
# ##### para crear un data frame a traves de un archivo excel ya subido al home

# %%
import pandas as pd

# %%
df = pd.read_excel('trepanos.xlsx', header=None)

# %% [markdown]
# ##### por defecto solo nos muestra las 4 primeras filas

# %%
df.head()
# Out:
#      0          1         2         3              4          5  6  7     8
# 0  A10    TRACK28      EEUU       PDC  SIN COJINETES 2018-01-10  2  1  1500
# 1  A20    EZ CASE      EEUU  MONOCONO      SIN SELLO 2019-06-30  7  2  2100
# 2  A30     RW2021    MEXICO    BICONO      SIN SELLO 2019-06-30  0  1  1200
# 3  A40   POWER-56  ALEMANIA       PDC  SIN COJINETES 2019-06-30  4  3   690
# 4  A50  WZP54-MIT    MEXICO       PDC  SIN COJINETES 2018-01-10  2  1   875

# %%
df.head(2)
# Out:
#      0        1     2         3              4          5  6  7     8
# 0  A10  TRACK28  EEUU       PDC  SIN COJINETES 2018-01-10  2  1  1500
# 1  A20  EZ CASE  EEUU  MONOCONO      SIN SELLO 2019-06-30  7  2  2100

# %% [markdown]
# ##### por defecto nos muestra las ultimas 5 filas

# %%
df.tail()
# Out:
#        0         1        2        3          4          5  6  7     8
# 36  A370     XZ-42     EEUU   CORONA  CON SELLO 2018-01-10  7  3  1080
# 37  A380  EXT28-10     EEUU   BICONO  SIN SELLO 2020-02-15  2  1  1250
# 38  A390  EXT28-20   MEXICO  TRICONO  CON SELLO 2020-02-15  4  2  1000
# 39  A400     XZ-72  FRANCIA   CORONA  CON SELLO 2018-01-10  7  3  1080
# 40  A410     XZ-82   MEXICO   BICONO  SIN SELLO 2020-02-15  2  1  1250

# %%
df.tail(3)
# Out:
#        0         1        2        3          4          5  6  7     8
# 38  A390  EXT28-20   MEXICO  TRICONO  CON SELLO 2020-02-15  4  2  1000
# 39  A400     XZ-72  FRANCIA   CORONA  CON SELLO 2018-01-10  7  3  1080
# 40  A410     XZ-82   MEXICO   BICONO  SIN SELLO 2020-02-15  2  1  1250

# %% [markdown]
# ##### Por motivos practicos, supongamos que mi archivo excel no tenga nombre en las cabezas de cada columna

# %%
nombres = ['Nº_INVENTARIO','NOMBRE_DEL_TREPANO','PAIS-ORIGEN','TIPO','COJINETES','FECHA-COMPRA','DESGASTE','CANT','COSTO']

# %%
nombres
# Out:
# ['Nº_INVENTARIO',
#  'NOMBRE_DEL_TREPANO',
#  'PAIS-ORIGEN',
#  'TIPO',
#  'COJINETES',
#  'FECHA-COMPRA',
#  'DESGASTE',
#  'CANT',
#  'COSTO']

# %%
df.columns=nombres

# %%
df
# Out:
#    Nº_INVENTARIO NOMBRE_DEL_TREPANO PAIS-ORIGEN      TIPO      COJINETES  \
# 0            A10            TRACK28        EEUU       PDC  SIN COJINETES
# 1            A20            EZ CASE        EEUU  MONOCONO      SIN SELLO
# 2            A30             RW2021      MEXICO    BICONO      SIN SELLO
# 3            A40           POWER-56    ALEMANIA       PDC  SIN COJINETES
# 4            A50          WZP54-MIT      MEXICO       PDC  SIN COJINETES
# 5            A60      NAT-DIAM/2222        EEUU    CORONA      CON SELLO
# 6            A70              XZ-32        EEUU    CORONA      CON SELLO
# 7            A80     ESTANDAR XZ-32      MEXICO   TRICONO      CON SELLO
# 8            A90           HEDGEHOG     FRANCIA    CORONA      CON SELLO
# 9           A100         NEW-IRON78        EEUU   TRICONO      CON SELLO
# 10          A110           BALLASET      MEXICO   TRICONO      CON SELLO
# 11          A120           EXODUS32     FRANCIA   TRICONO      CON SELLO
# ...

# %%
df.columns
# Out:
# Index(['Nº_INVENTARIO', 'NOMBRE_DEL_TREPANO', 'PAIS-ORIGEN', 'TIPO',
#        'COJINETES', 'FECHA-COMPRA', 'DESGASTE', 'CANT', 'COSTO'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=41, step=1)

# %%
df.shape
# Out:
# (41, 9)

# %%
df['TIPO'].value_counts()
# Out:
# TRICONO     14
# CORONA      12
# BICONO       8
# PDC          6
# MONOCONO     1
# Name: TIPO, dtype: int64

# %%
df.T
# Out:
#                                      0                    1   \
# Nº_INVENTARIO                       A10                  A20
# NOMBRE_DEL_TREPANO              TRACK28              EZ CASE
# PAIS-ORIGEN                        EEUU                 EEUU
# TIPO                                PDC             MONOCONO
# COJINETES                 SIN COJINETES            SIN SELLO
# FECHA-COMPRA        2018-01-10 00:00:00  2019-06-30 00:00:00
# DESGASTE                              2                    7
# CANT                                  1                    2
# COSTO                              1500                 2100
#
#                                      2                    3   \
# Nº_INVENTARIO                       A30                  A40
# NOMBRE_DEL_TREPANO               RW2021             POWER-56
# PAIS-ORIGEN                      MEXICO             ALEMANIA
# TIPO                             BICONO                  PDC
# ...

# %% [markdown]
# ##### para mostrar los valores de cada trepano en orden ascendente

# %%
df.sort_values('COSTO')
# Out:
#    Nº_INVENTARIO NOMBRE_DEL_TREPANO PAIS-ORIGEN      TIPO      COJINETES  \
# 3            A40           POWER-56    ALEMANIA       PDC  SIN COJINETES
# 16          A170            GENESIS      MEXICO   TRICONO      CON SELLO
# 4            A50          WZP54-MIT      MEXICO       PDC  SIN COJINETES
# 10          A110           BALLASET      MEXICO   TRICONO      CON SELLO
# 11          A120           EXODUS32     FRANCIA   TRICONO      CON SELLO
# 38          A390           EXT28-20      MEXICO   TRICONO      CON SELLO
# 26          A270            TRACK38     FRANCIA    CORONA      CON SELLO
# 35          A360              XZ-32        EEUU   TRICONO      CON SELLO
# 29          A300              XZ-62     FRANCIA    BICONO      CON SELLO
# 25          A260           POWER-59      MEXICO       PDC  SIN COJINETES
# 31          A320        GENESIS HC6      MEXICO   TRICONO      CON SELLO
# 21          A220           POWER-60      MEXICO   TRICONO      CON SELLO
# ...

# %% [markdown]
# ##### para mostrar los costos en orden descendente

# %%
df.sort_values('COSTO', ascending=False)
# Out:
#    Nº_INVENTARIO NOMBRE_DEL_TREPANO PAIS-ORIGEN      TIPO      COJINETES  \
# 1            A20            EZ CASE        EEUU  MONOCONO      SIN SELLO
# 6            A70              XZ-32        EEUU    CORONA      CON SELLO
# 0            A10            TRACK28        EEUU       PDC  SIN COJINETES
# 17          A180           POWER-56        EEUU   TRICONO      CON SELLO
# 22          A230            TRACK39     FRANCIA       PDC  SIN COJINETES
# 7            A80     ESTANDAR XZ-32      MEXICO   TRICONO      CON SELLO
# 37          A380           EXT28-10        EEUU    BICONO      SIN SELLO
# 28          A290              XZ-52      MEXICO   TRICONO      CON SELLO
# 24          A250           POWER-57        EEUU   TRICONO      CON SELLO
# 19          A200           POWER-58     FRANCIA    BICONO      SIN SELLO
# 40          A410              XZ-82      MEXICO    BICONO      SIN SELLO
# 9           A100         NEW-IRON78        EEUU   TRICONO      CON SELLO
# ...

# %%
df[['NOMBRE_DEL_TREPANO','COSTO']]
# Out:
#    NOMBRE_DEL_TREPANO  COSTO
# 0             TRACK28   1500
# 1             EZ CASE   2100
# 2              RW2021   1200
# 3            POWER-56    690
# 4           WZP54-MIT    875
# 5       NAT-DIAM/2222   1100
# 6               XZ-32   1800
# 7      ESTANDAR XZ-32   1350
# 8            HEDGEHOG   1150
# 9          NEW-IRON78   1250
# 10           BALLASET    980
# 11           EXODUS32    986
# 12        WZP54-MIT/2   1210
# 13        GENESIS HCM   1050
# 14       MAN-SPEED/48   1060
# 15          EXT28-HGF   1200
# 16            GENESIS    780
# 17           POWER-56   1350
# 18            TRACK28   1150
# 19           POWER-58   1250
# 20        GENESIS HC3   1210
# 21           POWER-60   1050
# 22            TRACK39   1350
# 23            TRACK40   1150
# 24           POWER-57   1250
# 25           POWER-59   1050
# 26            TRACK38   1000
# 27        GENESIS HC1   1080
# 28              XZ-52   1250
# 29              XZ-62   1050
# 30        GENESIS HC2   1210
# ...

# %%
df[:3]
# Out:
#   Nº_INVENTARIO NOMBRE_DEL_TREPANO PAIS-ORIGEN      TIPO      COJINETES  \
# 0           A10            TRACK28        EEUU       PDC  SIN COJINETES
# 1           A20            EZ CASE        EEUU  MONOCONO      SIN SELLO
# 2           A30             RW2021      MEXICO    BICONO      SIN SELLO
#
#   FECHA-COMPRA  DESGASTE  CANT  COSTO
# 0   2018-01-10         2     1   1500
# 1   2019-06-30         7     2   2100
# 2   2019-06-30         0     1   1200

# %%
df.iloc[[4,10], [1,8]]
# Out:
#    NOMBRE_DEL_TREPANO  COSTO
# 4           WZP54-MIT    875
# 10           BALLASET    980

# %% [markdown]
# ##### para obtener valores de costo mayores a un numero

# %%
df[df['COSTO']>1250]
# Out:
#    Nº_INVENTARIO NOMBRE_DEL_TREPANO PAIS-ORIGEN      TIPO      COJINETES  \
# 0            A10            TRACK28        EEUU       PDC  SIN COJINETES
# 1            A20            EZ CASE        EEUU  MONOCONO      SIN SELLO
# 6            A70              XZ-32        EEUU    CORONA      CON SELLO
# 7            A80     ESTANDAR XZ-32      MEXICO   TRICONO      CON SELLO
# 17          A180           POWER-56        EEUU   TRICONO      CON SELLO
# 22          A230            TRACK39     FRANCIA       PDC  SIN COJINETES
#
#    FECHA-COMPRA  DESGASTE  CANT  COSTO
# 0    2018-01-10         2     1   1500
# 1    2019-06-30         7     2   2100
# 6    2018-01-11         0     2   1800
# 7    2018-01-12         2     1   1350
# 17   2020-02-18         7     1   1350
# 22   2019-06-30         7     1   1350

# %% [markdown]
# ##### para obtener valores mayores que y menores que

# %%
df[(df['COSTO']>1250)&(df['COSTO']<1800)]
# Out:
#    Nº_INVENTARIO NOMBRE_DEL_TREPANO PAIS-ORIGEN     TIPO      COJINETES  \
# 0            A10            TRACK28        EEUU      PDC  SIN COJINETES
# 7            A80     ESTANDAR XZ-32      MEXICO  TRICONO      CON SELLO
# 17          A180           POWER-56        EEUU  TRICONO      CON SELLO
# 22          A230            TRACK39     FRANCIA      PDC  SIN COJINETES
#
#    FECHA-COMPRA  DESGASTE  CANT  COSTO
# 0    2018-01-10         2     1   1500
# 7    2018-01-12         2     1   1350
# 17   2020-02-18         7     1   1350
# 22   2019-06-30         7     1   1350

# %% [markdown]
# ##### para saber si hubo algun valor perdido en el data frame

# %%
df.isna().sum()
# Out:
# Nº_INVENTARIO         0
# NOMBRE_DEL_TREPANO    0
# PAIS-ORIGEN           0
# TIPO                  0
# COJINETES             0
# FECHA-COMPRA          0
# DESGASTE              0
# CANT                  0
# COSTO                 0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# ##### si ahora voy a importar de la forma:

# %%
import numpy as np

# %%
df['DESGASTE'][:2] = np.nan
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#   Nº_INVENTARIO NOMBRE_DEL_TREPANO PAIS-ORIGEN      TIPO      COJINETES  \
# 0           A10            TRACK28        EEUU       PDC  SIN COJINETES
# 1           A20            EZ CASE        EEUU  MONOCONO      SIN SELLO
# 2           A30             RW2021      MEXICO    BICONO      SIN SELLO
# 3           A40           POWER-56    ALEMANIA       PDC  SIN COJINETES
# 4           A50          WZP54-MIT      MEXICO       PDC  SIN COJINETES
#
#   FECHA-COMPRA  DESGASTE  CANT  COSTO
# 0   2018-01-10       NaN     1   1500
# 1   2019-06-30       NaN     2   2100
# 2   2019-06-30       0.0     1   1200
# 3   2019-06-30       4.0     3    690
# 4   2018-01-10       2.0     1    875

# %%
df.isna().sum()
# Out:
# Nº_INVENTARIO         0
# NOMBRE_DEL_TREPANO    0
# PAIS-ORIGEN           0
# TIPO                  0
# COJINETES             0
# FECHA-COMPRA          0
# DESGASTE              2
# CANT                  0
# COSTO                 0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 2

# %% [markdown]
# ##### me dice que hay 2 valores perdidos, entonces para rellenar:

# %%
df['DESGASTE'].fillna(2)
# Out:
# 0     2.0
# 1     2.0
# 2     0.0
# 3     4.0
# 4     2.0
# 5     7.0
# 6     0.0
# 7     2.0
# 8     2.0
# 9     4.0
# 10    7.0
# 11    0.0
# 12    2.0
# 13    7.0
# 14    7.0
# 15    2.0
# 16    4.0
# 17    7.0
# 18    7.0
# 19    2.0
# 20    4.0
# 21    7.0
# 22    7.0
# 23    2.0
# 24    4.0
# 25    7.0
# 26    4.0
# 27    4.0
# 28    4.0
# 29    4.0
# 30    7.0
# 31    2.0
# 32    7.0
# 33    2.0
# 34    4.0
# 35    4.0
# 36    7.0
# 37    2.0
# 38    4.0
# 39    7.0
# 40    2.0
# Name: DESGASTE, dtype: float64

# %%
df['DESGASTE'] = df['DESGASTE'].fillna(2)

# %%
df.head()
# Out:
#   Nº_INVENTARIO NOMBRE_DEL_TREPANO PAIS-ORIGEN      TIPO      COJINETES  \
# 0           A10            TRACK28        EEUU       PDC  SIN COJINETES
# 1           A20            EZ CASE        EEUU  MONOCONO      SIN SELLO
# 2           A30             RW2021      MEXICO    BICONO      SIN SELLO
# 3           A40           POWER-56    ALEMANIA       PDC  SIN COJINETES
# 4           A50          WZP54-MIT      MEXICO       PDC  SIN COJINETES
#
#   FECHA-COMPRA  DESGASTE  CANT  COSTO
# 0   2018-01-10       2.0     1   1500
# 1   2019-06-30       2.0     2   2100
# 2   2019-06-30       0.0     1   1200
# 3   2019-06-30       4.0     3    690
# 4   2018-01-10       2.0     1    875

# %%
df['CANT'].apply(lambda x: -x)
# Out:
# 0    -1
# 1    -2
# 2    -1
# 3    -3
# 4    -1
# 5    -1
# 6    -2
# 7    -1
# 8    -3
# 9    -2
# 10   -3
# 11   -1
# 12   -2
# 13   -4
# 14   -2
# 15   -1
# 16   -2
# 17   -1
# 18   -3
# 19   -2
# 20   -3
# 21   -1
# 22   -1
# 23   -3
# 24   -2
# 25   -3
# 26   -1
# 27   -1
# 28   -2
# 29   -2
# 30   -3
# 31   -2
# 32   -3
# 33   -1
# 34   -1
# 35   -2
# 36   -3
# 37   -1
# 38   -2
# 39   -3
# 40   -1
# Name: CANT, dtype: int64

# %% [markdown]
# ##### para elevar al cuadrado algun valor

# %%
df['CANT'].apply(lambda x: x**2)
# Out:
# 0      1
# 1      4
# 2      1
# 3      9
# 4      1
# 5      1
# 6      4
# 7      1
# 8      9
# 9      4
# 10     9
# 11     1
# 12     4
# 13    16
# 14     4
# 15     1
# 16     4
# 17     1
# 18     9
# 19     4
# 20     9
# 21     1
# 22     1
# 23     9
# 24     4
# 25     9
# 26     1
# 27     1
# 28     4
# 29     4
# 30     9
# 31     4
# 32     9
# 33     1
# 34     1
# 35     4
# 36     9
# 37     1
# 38     4
# 39     9
# 40     1
# Name: CANT, dtype: int64

# %% [markdown]
# ##### para devolver la media del costo de cada tipo de trepano

# %%
df_group = df.groupby('TIPO')['COSTO'].mean()

# %%
df_group.name='media_del_costo'

# %%
df_group
# Out:
# TIPO
# BICONO      1147.500000
# CORONA      1183.333333
# MONOCONO    2100.000000
# PDC         1112.500000
# TRICONO     1112.571429
# Name: media_del_costo, dtype: float64

# %% [markdown]
# ##### para crear otra columna ahora con la media del costo

# %%
df_join = df.join(df_group, on=['TIPO'], how='inner')

# %%
df_join.head()
# Out:
#    Nº_INVENTARIO NOMBRE_DEL_TREPANO PAIS-ORIGEN TIPO      COJINETES  \
# 0            A10            TRACK28        EEUU  PDC  SIN COJINETES
# 3            A40           POWER-56    ALEMANIA  PDC  SIN COJINETES
# 4            A50          WZP54-MIT      MEXICO  PDC  SIN COJINETES
# 22          A230            TRACK39     FRANCIA  PDC  SIN COJINETES
# 25          A260           POWER-59      MEXICO  PDC  SIN COJINETES
#
#    FECHA-COMPRA  DESGASTE  CANT  COSTO  media_del_costo
# 0    2018-01-10       2.0     1   1500           1112.5
# 3    2019-06-30       4.0     3    690           1112.5
# 4    2018-01-10       2.0     1    875           1112.5
# 22   2019-06-30       7.0     1   1350           1112.5
# 25   2020-02-15       7.0     3   1050           1112.5

# %%
import matplotlib.pyplot as plt

# %%
df_join['media_del_costo'].plot()
# Out:
# <AxesSubplot:>

# %%
df_join['DESGASTE'].plot()
# Out:
# <AxesSubplot:>

# %%
df_join.plot()
# Out:
# <AxesSubplot:>

# %%
df_join.plot(figsize=[7,12])
# Out:
# <AxesSubplot:>

# %%
df_join['COSTO'].plot(kind='bar')
# Out:
# <AxesSubplot:>
